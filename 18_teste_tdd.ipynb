# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiatito/2024.1-Algoritmos-e-estrutura-de-dados-Leticia-Tito/blob/main/18_teste_tdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
import importlib.util
import unittest

drive.mount('/content/drive')

#navegar pro diretorio de destino
os.chdir('/content/drive/MyDrive/Colab Notebooks/ALG_EST')

# Perguntar ao usuário o caminho do arquivo no Google Drive
caminho = "/content/drive/MyDrive/Colab Notebooks/ALG_EST/18_tdd.ipynb"
# Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/20241_alg_est/18_tdd.ipynb'):

# Exibir o caminho fornecido pelo usuário
print(f"O caminho fornecido foi: {caminho}")

# Converter o notebook para um script Python
# !jupyter nbconvert --to script "{caminho}"

# Substituir a extensão '.ipynb' por '.py' para localizar o arquivo convertido
caminho_py = caminho.replace('.ipynb', '.py')

# Caso o arquivo tenha sido gerado como '.txt', renomeie para '.py'
if os.path.exists(caminho_py.replace('.py', '.txt')):
    os.rename(caminho_py.replace('.py', '.txt'), caminho_py)

# Importar o script Python gerado
spec = importlib.util.spec_from_file_location("tdd_module", caminho_py)
tdd_module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(tdd_module)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# O caminho fornecido foi: /content/drive/MyDrive/Colab Notebooks/ALG_EST/18_tdd.ipynb
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/ALG_EST/18_tdd.ipynb to script
# [NbConvertApp] Writing 413 bytes to /content/drive/MyDrive/Colab Notebooks/ALG_EST/18_tdd.txt

# %%
#TDD - O Test-Driven Development (TDD), ou Desenvolvimento Orientado a Testes,
#é uma metodologia de desenvolvimento de software que enfatiza a criação e
#execução de testes antes mesmo do desenvolvimento do código

#programa para avaliar a saída de uma função dado uma entrada
import random

#esqueleto de uma função para gerar uma lista de 28 numeros aleatorios, entre 1 e 100
def gerar_lista_aleatoria():
  lista = []
  for i in range(28)
  lista.append(random.randint(1,100))
  return lista
print(gerar_lista_aleatoria())
  #pass
  #return [random.randint()]

#Esqueleto de uma função para gerar uma lista de 28 numeros aleatorios distintos entre 1 e 100
def gerar_lista_aleatoria_distintos():
  pass

#esqueleto de uma função para embaralhar a lista
def embaralhar_lista(): #lembrar que os alunos não colocaram esse
  random.shuffle(lista)
  return lista
print(embaralhar_lista)
  #pass
  #random.shuffle(lista)x
  #return lista
# Out:
#   File "<ipython-input-4-6329b15ee961>", line 11
#     for i in range(28)
#                       ^
# SyntaxError: expected ':'
