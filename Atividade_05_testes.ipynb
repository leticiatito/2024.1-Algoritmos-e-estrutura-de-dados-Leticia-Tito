# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiatito/2024.1-Algoritmos-e-estrutura-de-dados-Leticia-Tito/blob/main/Atividade_05_testes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive  # Tratar Google Drive
import os                       # Acessar comandos do SO
import importlib.util           # Importação do arquivo
import unittest                 # Realizar os testes unitários

# Montando a pasta no Google Drive
drive.mount('/content/drive')

# Navegar para o diretório de destino
os.chdir('/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados')

# Função para perguntar ao usuário o caminho do arquivo no Google Drive
def obter_caminho_arquivo():
    caminho = input("Digite o caminho completo do arquivo no Google Drive (ex: '/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/atividade_05_palindromo.ipynb'): ")
    print(f"O caminho fornecido foi: {caminho}")
    return caminho

# Converter notebook para script Python e importar o módulo
def importar_modulo(caminho_notebook):
    # Converter o notebook para um script Python
    # !jupyter nbconvert --to script "{caminho_notebook}"

    # Substituir a extensão '.ipynb' por '.py' para localizar o arquivo convertido
    caminho_py = caminho_notebook.replace('.ipynb', '.py')

    # Caso o arquivo tenha sido gerado como '.txt', renomeie para '.py'
    if os.path.exists(caminho_py.replace('.py', '.txt')):
        os.rename(caminho_py.replace('.py', '.txt'), caminho_py)

    # Importar o script Python gerado
    spec = importlib.util.spec_from_file_location("module", caminho_py)
    modulo = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(modulo)
    return modulo

#importar ja com caminhos
palindromo_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/atividade_05_palindromo.ipynb")
contagem_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_contagem.ipynb")
inverter_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_inverter.ipynb")
converter_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_converter.ipynb")
contar_module = importar_modulo("/content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_contar.ipynb")


# Importar os módulos
#palindromo_module = importar_modulo(obter_caminho_arquivo())
#contagem_module = importar_modulo(obter_caminho_arquivo())
#inverter_module = importar_modulo(obter_caminho_arquivo())
#converter_module = importar_modulo(obter_caminho_arquivo())
#contar_module = importar_modulo(obter_caminho_arquivo())

# Testes Unificados
class TestListaDeExercicios(unittest.TestCase):

    # Testes para o palíndromo
    def test_palindromo_simples(self):
        self.assertTrue(palindromo_module.eh_palindromo("arara"))

    def test_palindromo_com_espacos(self):
        self.assertTrue(palindromo_module.eh_palindromo("subi no onibus"))

    def test_nao_palindromo(self):
        self.assertFalse(palindromo_module.eh_palindromo("algoritmos"))

    # Testes para contagem de palavras
    def test_contagem_palavra(self):
        with open("teste.txt", "w") as f:
            f.write("Ola universo.")
        self.assertEqual(contagem_module.contar_palavra("teste.txt", "teste"), 2)

    def test_palavra_nao_presente(self):
        with open("teste.txt", "w") as f:
            f.write("Ola universo.")
        self.assertEqual(contagem_module.contar_palavra("teste.txt", "mundo"), 0)

    # Testes para inverter string
    def test_inverter_simples(self):
        self.assertEqual(inverter_module.inverter_string("mundo/"), "/odnum")

    def test_inverter_com_espacos(self):
        self.assertEqual(inverter_module.inverter_string("Hello, world!"), "!dlrow ,olleH")

    def test_inverter_vazio(self):
        self.assertEqual(inverter_module.inverter_string("/"), "/")

    # Testes para converter para maiúsculas
    def test_converter(self):
        with open("arquivo_saida.txt", "w") as f:
            f.write("teste de arquivo de texto que será convertido para maiúsculas. Aprendendo a manipular arquivos de texto")
        converter_module.converter_para_maiusculas("arquivo_entrada.txt", "arquivo_saida.txt")
        with open("arquivo_entrada.txt", "r") as f:
            conteudo = f.read()
        self.assertEqual(conteudo, "TESTE DE ARQUIVO DE TEXTO QUE SERÁ CONVERTIDO PARA MAIÚSCULAS. APRENDENDO A MANIPULAR ARQUIVOS DE TEXTO")

    # Testes para contar caracteres
    def test_contagem_simples(self):
        self.assertEqual(contar_module.contar_caracteres("abcabc"), {'a': 2, 'b': 2, 'c': 2})

    def test_contagem_com_espacos(self):
        self.assertEqual(contar_module.contar_caracteres("a b c a b c"), {'a': 2, ' ': 5, 'b': 2, 'c': 2})

    def test_contagem_vazio(self):
        self.assertEqual(contar_module.contar_caracteres(""), {})

if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/atividade_05_palindromo.ipynb to script
# [NbConvertApp] Writing 348 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/atividade_05_palindromo.txt
# True
# True
# False
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_contagem.ipynb to script
# [NbConvertApp] Writing 711 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_contagem.txt
# 0
# 0
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_inverter.ipynb to script
# [NbConvertApp] Writing 524 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_inverter.txt
# as string originais : mundoolá, mundo!/
# a string invertidaoriginaiss originais: /!odnum ,áloodnum
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_converter.ipynb to script
# [NbConvertApp] Writing 933 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_converter.txt
# Arquivo convertido com sucesso
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_contar.ipynb to script
# [NbConvertApp] Writing 489 bytes to /content/drive/MyDrive/Colab Notebooks/2024.1_Algoritmos e Estruturas de dados/Atividade_05_contar.txt
# test_contagem_com_espacos (__main__.TestListaDeExercicios) ... ok
# test_contagem_palavra (__main__.TestListaDeExercicios) ... FAIL
# test_contagem_simples (__main__.TestListaDeExercicios) ... ok
# test_contagem_vazio (__main__.TestListaDeExercicios) ... ok
# test_converter (__main__.TestListaDeExercicios) ... FAIL
# test_inverter_com_espacos (__main__.TestListaDeExercicios) ... FAIL
# test_inverter_simples (__main__.TestListaDeExercicios) ... FAIL
# test_inverter_vazio (__main__.TestListaDeExercicios) ... FAIL
# test_nao_palindromo (__main__.TestListaDeExercicios) ... ok
# test_palavra_nao_presente (__main__.TestListaDeExercicios) ... ok
# test_palindromo_com_espacos (__main__.TestListaDeExercicios) ... ok
# test_palindromo_simples (__main__.TestListaDeExercicios) ... ok
#
# ======================================================================
# FAIL: test_contagem_palavra (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-3-dd11b49d9ea5>", line 68, in test_contagem_palavra
#     self.assertEqual(contagem_module.contar_palavra("teste.txt", "teste"), 2)
# AssertionError: 0 != 2
#
# ======================================================================
# FAIL: test_converter (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-3-dd11b49d9ea5>", line 92, in test_converter
#     self.assertEqual(conteudo, "TESTE DE ARQUIVO DE TEXTO QUE SERÁ CONVERTIDO PARA MAIÚSCULAS. APRENDENDO A MANIPULAR ARQUIVOS DE TEXTO")
# AssertionError: 'teste de arquivo de texto que será conver[58 chars]exto' != 'TESTE DE ARQUIVO DE TEXTO QUE SERÁ CONVER[58 chars]EXTO'
# - teste de arquivo de texto que será convertido para maiúsculas. Aprendendo a manipular arquivos de texto
# + TESTE DE ARQUIVO DE TEXTO QUE SERÁ CONVERTIDO PARA MAIÚSCULAS. APRENDENDO A MANIPULAR ARQUIVOS DE TEXTO
#
#
# ======================================================================
# FAIL: test_inverter_com_espacos (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-3-dd11b49d9ea5>", line 80, in test_inverter_com_espacos
#     self.assertEqual(inverter_module.inverter_string("Hello, world!"), "!dlrow ,olleH")
# AssertionError: ('mundoolá, mundo!/', '/!odnum ,áloodnum') != '!dlrow ,olleH'
#
# ======================================================================
# FAIL: test_inverter_simples (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-3-dd11b49d9ea5>", line 77, in test_inverter_simples
#     self.assertEqual(inverter_module.inverter_string("mundo/"), "/odnum")
# AssertionError: ('mundoolá, mundo!/', '/!odnum ,áloodnum') != '/odnum'
#
# ======================================================================
# FAIL: test_inverter_vazio (__main__.TestListaDeExercicios)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-3-dd11b49d9ea5>", line 83, in test_inverter_vazio
#     self.assertEqual(inverter_module.inverter_string("/"), "/")
# AssertionError: ('mundoolá, mundo!/', '/!odnum ,áloodnum') != '/'
#
# ----------------------------------------------------------------------
# Ran 12 tests in 0.110s
#
# FAILED (failures=5)
# {'a': 2, 'b': 2, 'c': 2}
# {'a': 2, ' ': 5, 'b': 2, 'c': 2}
# {'/': 1}
# Arquivo convertido com sucesso
